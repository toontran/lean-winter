# %% [markdown]
# # Communicating with Lean

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Communicating-with-Lean" data-toc-modified-id="Communicating-with-Lean-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Communicating with Lean</a></span><ul class="toc-item"><li><span><a href="#Lean-Server" data-toc-modified-id="Lean-Server-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lean Server</a></span></li><li><span><a href="#Testing-tactics-with-the-Lean-Server" data-toc-modified-id="Testing-tactics-with-the-Lean-Server-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Testing tactics with the Lean Server</a></span><ul class="toc-item"><li><span><a href="#Speed-and-robustness" data-toc-modified-id="Speed-and-robustness-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Speed and robustness</a></span></li><li><span><a href="#Stepping-through-a-full-proof" data-toc-modified-id="Stepping-through-a-full-proof-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Stepping through a full proof</a></span></li></ul></li><li><span><a href="#Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python" data-toc-modified-id="Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creating a simple Lean solver (with breath first search) in Python</a></span></li><li><span><a href="#Custom-printing-of-Lean-expressions" data-toc-modified-id="Custom-printing-of-Lean-expressions-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Custom printing of Lean expressions</a></span></li><li><span><a href="#Current-issues" data-toc-modified-id="Current-issues-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Current issues</a></span><ul class="toc-item"><li><span><a href="#Privately-defined-terms" data-toc-modified-id="Privately-defined-terms-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Privately defined terms</a></span></li><li><span><a href="#Term-blowup" data-toc-modified-id="Term-blowup-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Term blowup</a></span></li><li><span><a href="#Missing-@-symbols" data-toc-modified-id="Missing-@-symbols-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Missing @ symbols</a></span></li><li><span><a href="#Extra-@-sysmbols-(or-maybe-a-missing-case-in-the-Lean-parser)" data-toc-modified-id="Extra-@-sysmbols-(or-maybe-a-missing-case-in-the-Lean-parser)-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Extra <code>@</code> sysmbols (or maybe a missing case in the Lean parser)</a></span></li><li><span><a href="#Implicit-and-type-class-assumptions" data-toc-modified-id="Implicit-and-type-class-assumptions-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>Implicit and type class assumptions</a></span></li><li><span><a href="#Let-expressions" data-toc-modified-id="Let-expressions-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>Let expressions</a></span></li><li><span><a href="#Other" data-toc-modified-id="Other-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>Other</a></span></li></ul></li><li><span><a href="#TODOs" data-toc-modified-id="TODOs-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>TODOs</a></span></li><li><span><a href="#What-I-want-from-Lean-4" data-toc-modified-id="What-I-want-from-Lean-4-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>What I want from Lean 4</a></span></li></ul></li></ul></div>

# %% [markdown]
# This is a hacky prototype showing how one can use Lean's server for communication between Lean and another program.  We have in mind implementing something like HOList for Lean. The main idea is that theorem proving is like a puzzle similar to the Rubik cube.  One has states and actions one can perform to move to other states.  This states are goals (or lists of goals) and the actions are tactics.
#
# What we build here is an interface where one says to Lean "apply this tactic to this goal" and Lean says whether that tactic succeeds and if so what the new list of goals are.  It is written in a Python notebook, but the ideas transcend languages.

# %%
import subprocess
import tempfile
import json
from pprint import pprint
import time
from datetime import datetime
import collections
from IPython.display import display

# %% [markdown]
# ## Lean Server
# This class starts up a Lean server and communicates with it.  There are a number of requests one can make to the Lean server, but we only need one or two.  To understand the Lean server, it is important to know it is not like a REPL, but more like the LSP.  It is designed to partial compile and comment on files as they are being written.  The use here is more of a hack (and it is unfortunately quite a bit slow we will see).
#
# One communicates to Lean by sending JSON requests and getting back responses.  We only need one or two request types for our purposes.  The first request we need is a "sync" request.  It sends a "file" to Lean to be synced.  (The file doesn't actually need to exist.)  The second request, an "info" request, asks Lean to provide more information about particular places in the code.  Unfortunately, the responses to the requests don't actually provide a lot of direct answers.  Especially for the "sync" request, one has to wait for an "all_messages" request to provide answers.  (And even then, it is difficult to determine that the response you got is up-to-date with the current Lean file.  We've employed a lot of tricks to make sure we are getting the most up-to-date information from Lean.)  Our class will store any "all_messages" responses it sees into a queue for latter processing.
#
# Ultimately, the "info" requests turned out not to be a reliable as we hoped, so we just use the "sync" request and only use the "info" request to prevent blocking of the channel.

# %%
import os
from os.path import expanduser


class LeanServer:
    """
    Open up a Lean server and communicate with it.  
    
    Right now it only has support for the "sync" and "info" requests (and their)
    corresponding responses.  It does however, store all "all_messages" response
    into a queue for later processing.
    """
    
    def __init__(self):
        self.cntr = -1
        self.cntr2 = -1
        self.all_messages = []
        self.all_messages_time = -1
        self.current_tasks = []
        self.current_tasks_time = -1
        home = expanduser("~")
        self.proc = subprocess.Popen([os.path.join(home, '.elan/bin/lean'), '--server'], 
                    universal_newlines=True, 
                    stdin=subprocess.PIPE, # pipe STDIN and STDOUT to send and receive messages
                    stdout=subprocess.PIPE, 
                    #stderr=subprocess.PIPE
                )
    
    # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.proc.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.proc.__exit__(type, value, traceback)
    
    def seq_num(self):
        self.cntr += 1
        return self.cntr
    
    def send_request(self, request, expected_response, verbose=False, sleep=0.0):
        seq_num = self.seq_num()
        request1 = request.copy()
        request1['seq_num'] = seq_num
        j = json.dumps(request1)
        
        # TODO: Use logging instead
        if verbose:
            print()
            print("=>:", datetime.now().strftime('%H:%M:%S.%f'))
            pprint(j)
            print()
        
        # send
        print(j, file=self.proc.stdin, flush=True)
        
        # wait for response
        time.sleep(sleep)
        while True:
            self.cntr2 += 1
            raw_output = self.proc.stdout.readline()
            output = json.loads(raw_output)
            if verbose:
                print("<=:", datetime.now().strftime('%H:%M:%S.%f'))
                pprint(output)
                print()
            if 'response' in output:
                if output['response'] == expected_response and output['seq_num'] == seq_num:
                    return output
                # TODO: Handle error differently.  It means the JSON is bad
                elif output['response'] == 'error':
                    return output
                # record messages since they may point to errors in the lean code
                elif output['response'] == 'all_messages':
                    self.all_messages = output['msgs']
                    self.all_messages_time = self.cntr2
                # record tasks to know when Lean has stopped processing file
                elif output['response'] == 'current_tasks':
                    self.current_tasks = output['tasks']
                    self.current_tasks_time = self.cntr2
    
    def send_sync_request(self, file_name, content, verbose=False):
        request = {
            'command':'sync',
            'file_name': file_name,
            "content": content,
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)
    
    def send_info_request(self, file_name, line, column, verbose=False):
        request = {            
            'command':'info',
            'file_name': file_name,
            'column': column,
            'line': line
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    response1 = lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end')
    time.sleep(1)
    response2 = lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1, 
        column=0)
    
    # the responses themselves aren't always useful
    display(response1)
    display(response2)
    
    # the "all_messages" responses are more useful
    display(lean_server.all_messages)
# Out:
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
# {'response': 'ok', 'seq_num': 1}
# [{'caption': '',
#   'file_name': '/tmp/fake_lean_file.lean',
#   'pos_col': 0,
#   'pos_line': 1,
#   'severity': 'warning',
#   'text': "declaration '[anonymous]' uses sorry"}]

# %% [markdown]
# In much of the code, use the optional parameter `verbose=True` to see the message traffic.

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end',
        verbose=True)
    lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1,
        column=0,
        verbose=True)
# Out:
# =>: 00:17:20.535402
# ('{"command": "sync", "file_name": "/tmp/fake_lean_file.lean", "content": '
#  '"example (p: Prop) : p = p := begin sorry end", "seq_num": 0}')
#
# <=: 00:17:20.724190
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
#
#
# =>: 00:17:20.724620
# ('{"command": "info", "file_name": "/tmp/fake_lean_file.lean", "column": 0, '
#  '"line": 1, "seq_num": 1}')
#
# <=: 00:17:20.741334
# {'response': 'ok', 'seq_num': 1}

# %% [markdown]
# ## Testing tactics with the Lean Server

# %% [markdown]
# Again, tactic-based theorem proving is like a puzzle.  You go from state to state exploring.  What we need is a way to test if we can use a tactic on a goal and what the next goals are.  This is what the LeanTacticTestingInterface does.  (Note, it is much faster to ask the Lean server about multiple goal-tactic pairs instead of just one at a time.)

# %%
# For storing information about a Lean goal
LeanGoal = collections.namedtuple('LeanGoal', ['universes', 'assumptions', 'conclusion'])

# %%
inspection_tools = r"""
namespace inspection_tools

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  o ← tactic.get_options,
  tactic.set_options (options.mk.set_bool `pp.all tt),
  f ← tactic.pp e,
  tactic.set_options o,  -- set back to before
  return $ to_string f
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_goal_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end inspection_tools
"""

default_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace "",  -- make more interesting
 return ()

end custom
"""

# %%
class LeanTacticTestingInterface:
    """
    Interface to test a tactic on a goal (or multiple tactics on multiple goals)
    """
    def __init__(self):
        self.lean_server = LeanServer()
        
        self.msg_cntr = 0
        self.file_name = 'dummy.lean'   # the name of the "file" being checked (not a real file)
        self.dummy_file = 'dummy.lean'  # a file always kept empty 
        self.eval_line_pos = None       # used for checking that a file is complete
        
        # set up a dummy file for later use
        self.lean_server.send_sync_request(file_name=self.dummy_file, content="")
        
        # one can implement their own custom state trace.  This is the default.
        self.custom_code = default_custom_code
    
     # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.lean_server.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.lean_server.__exit__(type, value, traceback)
        
    def parse_state(self, universes, goal_state):
        """
        Parses the trace string returned by trace_goal_state
        """
        lines = iter(' '.join(l.split()) for l in goal_state.split("\n\n"))
        
        goal_cnt = int(next(lines).split()[-1])
        
        goals = []
        for _ in range(goal_cnt):
            target = next(lines)
            assump_cnt = int(next(lines).split()[-1])
            assumptions = []
            for _ in range(assump_cnt):
                v = next(lines)
                tp = next(lines)
                assumptions.append(v + " : " + tp)
            goal = LeanGoal(universes, assumptions, target)
            goals.append(goal)

        return goals
    
    def check_content(self, content, verbose):
        """
        Have Lean check the contents of a Lean "file". 
        """
        self.msg_cntr += 1
        
        # empty out the previous file for good measure
        self.lean_server.send_sync_request(file_name=self.file_name, content="", verbose=verbose)
        
        # use a few different file names to help avoid old data in the messages
        self.file_name = 'fake_lean_file{}.lean'.format(self.msg_cntr % 10)
        
        # put an eval at the end to make sure the response is not from an old file
        extended_content = content + "\n#eval " + str(self.msg_cntr)
        self.eval_line_pos = extended_content.count("\n") + 1
        
        if verbose:
            print("-- {} --------------".format(self.file_name))
            for i, l in enumerate(extended_content.split('\n')):
                print("{:3}   {}".format(i+1, l))
            print("-------------------------")
            
        # send the file
        self.lean_server.send_sync_request(file_name=self.file_name, content=extended_content, verbose=verbose)
        
    def get_messages(self, verbose):
        """
        Get messages for the current content being checked.
        Return all the messages for that "file"
        
        This is really really hard to make robust.  How do I know Lean has finished
        or worst that Lean isn't still providing information from an old
        version of the file?
        """
        
        # wait for tasks to stop running
        tasks_stopped_time = None
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(file_name=self.dummy_file, line=1, column=0, verbose=verbose)
            
            # check that tasks are complete for file_name
            task_running = False
            for task in self.lean_server.current_tasks:
                if task['file_name'] == self.file_name:
                    task_running = True
                    break
            if not task_running:
                tasks_stopped_time = self.lean_server.current_tasks_time
                break
        else:
            raise TimeoutError("Tasks still running for {}:\n{}".format('file_name', "\n".join(self.lean_server.current_tasks)))
            
                
        # check that messages are complete by looking at eval at the end
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(self.dummy_file, line=1, column=0, verbose=verbose)
            
            # wait until messages are after current tasks
            #if self.lean_server.all_messages_time < tasks_stopped_time:
            #    continue
                
            # filter the messages to those for this "file" 
            # and also check for the final the eval statement
            filtered_messages = []
            messages_are_complete = False
            for msg in self.lean_server.all_messages:
                if msg['file_name'] == self.file_name:
                    if msg['pos_line'] < self.eval_line_pos:
                        filtered_messages.append(msg)
                    elif msg['pos_line'] == self.eval_line_pos and msg['caption'] == "eval result":
                        if msg['text'] == str(self.msg_cntr):
                            messages_are_complete = True
                        else:
                            break

            # clear messages
            self.lean_server.all_messages = []

            if messages_are_complete:
                return filtered_messages
            
        raise TimeoutError("Expecting eval result on line {} of file {} to be {}.  Run with verbose=True to check for error messages.".format(
                self.eval_line_pos, self.file_name, self.msg_cntr
        ))
    
    def preamble(self, imports):
        if imports:
            import_line = "import " + " ".join(imports) + "\n"
        else:
            import_line = ""
        
        return import_line + inspection_tools + "\n" + self.custom_code + "\n"
        
    def example_block(self, goal, tactic):
        block = ""
        # line: preamble + 9 * n + 0
        block += "section example_block\n"
        # line: preamble + 9 * n + 1
        if goal.universes:
            block += "universes " + " ".join(goal.universes) + "\n"
        else:
            block += "--no universes\n"
        # line: preamble + 9 * n + 2  
        block += "example "
        block += " ".join("(" + l.replace("\n", " ").replace("…", "_redacted_code_too_long_") + ")" for l in goal.assumptions)
        block += " : "
        block += goal.conclusion.replace("\n", " ").replace("…", "_redacted_code_too_long_") + " :=\n"
        # line: preamble + 9 * n + 3
        block += "begin\n"  
        # line: preamble + 9 * n + 4
        block += tactic + ",\n"
        # line: preamble + 9 * n + 5
        block += 'inspection_tools.trace_goal_state,\n' # goal state
        # line: preamble + 9 * n + 6
        block += 'custom.trace_custom_state,\n'         # custom trace
        # line: preamble + 9 * n + 7
        block += "end\n"
        # line: preamble + 9 * n + 8
        block += "end example_block\n"

        return block
            
    def apply_tactic_multiple(self, lean_goals, tactics, imports=[], verbose=False):
        assert len(lean_goals) == len(tactics)
        
        # build content
        preamble = self.preamble(imports)
        
        # this is the line (indexed from 1) that the first block will be on
        preamble_length = preamble.count("\n") + 1
        
        content = preamble
        for goal, tactic in zip(lean_goals, tactics):
            content += self.example_block(goal, tactic)
        
        # start checking the file
        self.check_content(content, verbose=verbose)
            
        # positions in the block
        theorem_line = 2
        tactic_line = 4
        goals_line = 5
        custom_state_line = 6
        block_length = 9
        
        for _ in range(1000):  # lazy timeout method
            # start checking the file
            msgs = self.get_messages(verbose=verbose)
        
            # extract data from messages
            results = [[None, None, [], []] for _ in lean_goals]
            for msg in msgs:
                block_line_pos = (msg['pos_line'] - preamble_length) % block_length
                block_num = (msg['pos_line'] - preamble_length) // block_length

                if msg['pos_line'] < preamble_length:
                    continue
                elif block_line_pos == goals_line and msg['severity'] == 'information':
                    results[block_num][0] = msg['text']
                elif block_line_pos == custom_state_line and msg['severity'] == 'information':
                    results[block_num][1] = msg['text']
                elif block_line_pos == tactic_line and msg['severity'] == 'error':
                    results[block_num][2].append(msg['text'])
                elif block_line_pos == theorem_line and msg['severity'] == 'error':
                    results[block_num][3].append(msg['text'])

            # parse data and check for completeness
            final_results = []
            complete = True
            for i, ((goal_state, custom_state, tactic_errors, theorem_errors), prev_goal) in enumerate(zip(results, lean_goals)):
                if theorem_errors:
                    result = ('theorem_error', theorem_errors, '')
                elif tactic_errors:
                    result = ('tactic_failure', tactic_errors, '')
                elif goal_state is not None and custom_state is not None:
                    result = ('success', self.parse_state(prev_goal.universes, goal_state), custom_state.strip())
                else:
                    complete = False  # need to get messages again
                    break

                final_results.append(result)

            if complete:
                return final_results
        
        raise TimeoutError("Lean server sessages are not as expected:\n{}".format("\n".join(msgs)))
        
    def apply_tactic(self, lean_goal, tactic, imports=[], verbose=False):
        """
        Apply tactic to a goal and see what you get.
        """
        
        result = self.apply_tactic_multiple([lean_goal], [tactic], imports=imports, verbose=verbose)
        return result[0]

# %% [markdown]
# We see if we apply `refl` to `p = p` we solve all the goals (hence the empty list returned).

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# One can also add universe levels, e.g. `u`, `v`, as follows:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# Imports can also be added to the `apply_tactic` call:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], ['α : Type u'],  'dlist.to_list (@dlist.empty α) = []')
    display(lean_interface.apply_tactic(goal, 'refl', imports=['data.dlist']))
# Out:
# ('success', [], '')

# %% [markdown]
# To see what is going on, we show the logs with `verbose=True`.  This also prints the file being sent to Lean.
#
# The main idea is that we encode everything we want to check into a Lean file, send that via a "sync" request, and read off the response from the messages.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl', verbose=True))
# Out:
# =>: 00:17:30.559992
# '{"command": "sync", "file_name": "dummy.lean", "content": "", "seq_num": 1}'
#
# <=: 00:17:30.561142
# {'message': 'file unchanged', 'response': 'ok', 'seq_num': 1}
#
# -- fake_lean_file1.lean --------------
#   1
#   2   namespace inspection_tools
#   3
#   4   def join (sep : string) : list string → string
#   5   | [x]     := x
#   6   | []      := ""
#   7   | (x::xs) := x ++ sep ++ join xs
#   8
#   9   meta def expr_to_string (e : expr bool.tt) : tactic string :=
#  10   do
#  11     o ← tactic.get_options,
#  12     tactic.set_options (options.mk.set_bool `pp.all tt),
#  13     f ← tactic.pp e,
#  14     tactic.set_options o,  -- set back to before
#  15     return $ to_string f
#  16
#  17   meta def local_cxt_to_string (v : expr bool.tt) : tactic string :=
#  18   do
#  19     tp ← tactic.infer_type v,
#  20     v_str ← expr_to_string v,
#  21     tp_str ← expr_to_string tp,
#  22     return $ v_str ++ "\n\n" ++ tp_str
#  23
#  24   meta def goal_to_string (g : expr) : tactic string :=
#  25   do
#  26     tactic.set_goals [g],
#  27     goal ← tactic.target,
#  28     local_cxt ← tactic.local_context,
#  29     let local_cxt_len := list.length local_cxt,
#  30     goal_str ← expr_to_string goal,
#  31     local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
#  32     let s1 := goal_str ++ "\n\n",
#  33     let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
#  34     let s3 := join "\n\n" local_cxt_strs,
#  35     return $ s1 ++ s2 ++ s3
#  36
#  37   meta def state_report : tactic string :=
#  38   do
#  39    gs ← tactic.get_goals,
#  40    -- loop over all goals (has effect of resetting the goal each time)
#  41    let gs_len := list.length gs,
#  42    goal_strings ← gs.mmap goal_to_string,
#  43    tactic.set_goals gs,  -- set goals back
#  44    let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
#  45    return s
#  46
#  47   meta def trace_goal_state : tactic unit :=
#  48   do
#  49    s ← state_report,
#  50    tactic.trace s,
#  51    return ()
#  52
#  53   end inspection_tools
#  54
#  55
#  56   namespace custom
#  57
#  58   meta def trace_custom_state : tactic unit :=
#  59   do
#  60    tactic.trace "",  -- make more interesting
#  61    return ()
#  62
#  63   end custom
#  64
#  65   section example_block
#  66   universes u v
#  67   example (a b: Type u) : a = a :=
#  68   begin
#  69   refl,
#  70   inspection_tools.trace_goal_state,
#  71   custom.trace_custom_state,
#  72   end
#  73   end example_block
#  74
#  75   #eval 1
# -------------------------
#
# =>: 00:17:30.571449
# ('{"command": "sync", "file_name": "fake_lean_file1.lean", "content": '
#  '"\\nnamespace inspection_tools\\n\\ndef join (sep : string) : list string '
#  '\\u2192 string\\n| [x]     := x\\n| []      := \\"\\"\\n| (x::xs) := x ++ '
#  'sep ++ join xs\\n\\nmeta def expr_to_string (e : expr bool.tt) : tactic '
#  'string :=\\ndo\\n  o \\u2190 tactic.get_options,\\n  tactic.set_options '
#  '(options.mk.set_bool `pp.all tt),\\n  f \\u2190 tactic.pp e,\\n  '
#  'tactic.set_options o,  -- set back to before\\n  return $ to_string f\\n  '
#  '\\nmeta def local_cxt_to_string (v : expr bool.tt) : tactic string := \\ndo '
#  '\\n  tp \\u2190 tactic.infer_type v,\\n  v_str \\u2190 expr_to_string v,\\n  '
#  'tp_str \\u2190 expr_to_string tp,\\n  return $ v_str ++ \\"\\\\n\\\\n\\" ++ '
#  'tp_str\\n\\nmeta def goal_to_string (g : expr) : tactic string :=\\ndo \\n  '
#  'tactic.set_goals [g],\\n  goal \\u2190 tactic.target,\\n  local_cxt \\u2190 '
#  'tactic.local_context,\\n  let local_cxt_len := list.length local_cxt,\\n  '
#  'goal_str \\u2190 expr_to_string goal,\\n  local_cxt_strs \\u2190 (list.mmap '
#  'local_cxt_to_string local_cxt),\\n  let s1 := goal_str ++ '
#  '\\"\\\\n\\\\n\\",\\n  let s2 := \\"Local Context Vars: \\" ++ (to_string '
#  'local_cxt_len) ++ \\"\\\\n\\\\n\\",\\n  let s3 := join \\"\\\\n\\\\n\\" '
#  'local_cxt_strs,\\n  return $ s1 ++ s2 ++ s3\\n\\nmeta def state_report : '
#  'tactic string :=\\ndo \\n gs \\u2190 tactic.get_goals,\\n -- loop over all '
#  'goals (has effect of resetting the goal each time)\\n let gs_len := '
#  'list.length gs,\\n goal_strings \\u2190 gs.mmap goal_to_string,\\n '
#  'tactic.set_goals gs,  -- set goals back\\n let s := \\"Goals: \\" ++ '
#  '(to_string gs_len) ++ \\"\\\\n\\\\n\\" ++ (join \\"\\\\n\\\\n\\" '
#  'goal_strings),\\n return s\\n \\nmeta def trace_goal_state : tactic unit '
#  ':=\\ndo \\n s \\u2190 state_report,\\n tactic.trace s,\\n return ()\\n\\nend '
#  'inspection_tools\\n\\n\\nnamespace custom\\n \\nmeta def trace_custom_state '
#  ': tactic unit :=\\ndo \\n tactic.trace \\"\\",  -- make more interesting\\n '
#  'return ()\\n\\nend custom\\n\\nsection example_block\\nuniverses u '
#  'v\\nexample (a b: Type u) : a = a '
#  ':=\\nbegin\\nrefl,\\ninspection_tools.trace_goal_state,\\ncustom.trace_custom_state,\\nend\\nend '
#  'example_block\\n\\n#eval 1", "seq_num": 2}')
#
# <=: 00:17:30.575989
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 2}
#
#
# =>: 00:17:30.576186
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 3}')
#
# <=: 00:17:30.579309
# {'is_running': True,
#  'response': 'current_tasks',
#  'tasks': [{'desc': 'parsing at line 1',
#             'end_pos_col': 8,
#             'end_pos_line': 75,
#             'file_name': 'fake_lean_file1.lean',
#             'pos_col': 0,
#             'pos_line': 1},
#            {'desc': 'parsing at line 1',
#             'end_pos_col': 1,
#             'end_pos_line': 1,
#             'file_name': 'dummy.lean',
#             'pos_col': 0,
#             'pos_line': 1}]}
#
# <=: 00:17:30.586757
# {'response': 'ok', 'seq_num': 3}
#
#
# =>: 00:17:30.586985
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 4}')
#
# <=: 00:17:30.587786
# {'response': 'ok', 'seq_num': 4}
#
#
# =>: 00:17:30.588261
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 5}')
#
# <=: 00:17:30.588958
# {'response': 'ok', 'seq_num': 5}
#
#
# =>: 00:17:30.589174
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 6}')
#
# <=: 00:17:30.590085
# {'response': 'ok', 'seq_num': 6}
#
#
# =>: 00:17:30.590297
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 7}')
#
# <=: 00:17:30.591218
# {'response': 'ok', 'seq_num': 7}
#
#
# =>: 00:17:30.591434
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 8}')
#
# <=: 00:17:30.592360
# {'response': 'ok', 'seq_num': 8}
#
#
# =>: 00:17:30.592468
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 9}')
#
# <=: 00:17:30.593218
# {'response': 'ok', 'seq_num': 9}
#
#
# =>: 00:17:30.593317
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 10}')
#
# <=: 00:17:30.594058
# {'response': 'ok', 'seq_num': 10}
#
#
# =>: 00:17:30.594156
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 11}')
#
# <=: 00:17:30.594948
# {'response': 'ok', 'seq_num': 11}
#
#
# =>: 00:17:30.595045
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 12}')
#
# <=: 00:17:30.595791
# {'response': 'ok', 'seq_num': 12}
#
#
# =>: 00:17:30.595887
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 13}')
#
# <=: 00:17:30.596656
# {'response': 'ok', 'seq_num': 13}
#
#
# =>: 00:17:30.596753
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 14}')
#
# <=: 00:17:30.597524
# {'response': 'ok', 'seq_num': 14}
#
#
# =>: 00:17:30.597729
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 15}')
#
# <=: 00:17:30.598616
# {'response': 'ok', 'seq_num': 15}
#
#
# =>: 00:17:30.598806
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 16}')
#
# <=: 00:17:30.599580
# {'response': 'ok', 'seq_num': 16}
#
#
# =>: 00:17:30.599769
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 17}')
#
# <=: 00:17:30.600533
# {'response': 'ok', 'seq_num': 17}
#
#
# =>: 00:17:30.600720
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 18}')
#
# <=: 00:17:30.601497
# {'response': 'ok', 'seq_num': 18}
#
#
# =>: 00:17:30.601682
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 19}')
#
# <=: 00:17:30.602438
# {'response': 'ok', 'seq_num': 19}
#
#
# =>: 00:17:30.602635
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 20}')
#
# <=: 00:17:30.603403
# {'response': 'ok', 'seq_num': 20}
#
#
# =>: 00:17:30.603539
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 21}')
#
# <=: 00:17:30.604164
# {'response': 'ok', 'seq_num': 21}
#
#
# =>: 00:17:30.604264
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 22}')
#
# <=: 00:17:30.604918
# {'response': 'ok', 'seq_num': 22}
#
#
# =>: 00:17:30.605017
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 23}')
#
# <=: 00:17:30.605657
# {'response': 'ok', 'seq_num': 23}
#
#
# =>: 00:17:30.605761
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 24}')
#
# <=: 00:17:30.606388
# {'response': 'ok', 'seq_num': 24}
#
#
# =>: 00:17:30.606487
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 25}')
#
# <=: 00:17:30.607154
# {'response': 'ok', 'seq_num': 25}
#
#
# =>: 00:17:30.607252
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 26}')
#
# <=: 00:17:30.608133
# {'response': 'ok', 'seq_num': 26}
#
#
# =>: 00:17:30.608383
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 27}')
#
# <=: 00:17:30.608887
# {'response': 'ok', 'seq_num': 27}
#
#
# =>: 00:17:30.608994
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 28}')
#
# <=: 00:17:30.609682
# {'response': 'ok', 'seq_num': 28}
#
#
# =>: 00:17:30.609780
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 29}')
#
# <=: 00:17:30.610425
# {'response': 'ok', 'seq_num': 29}
#
#
# =>: 00:17:30.610524
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 30}')
#
# <=: 00:17:30.611182
# {'response': 'ok', 'seq_num': 30}
#
#
# =>: 00:17:30.611516
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 31}')
#
# <=: 00:17:30.611958
# {'response': 'ok', 'seq_num': 31}
#
#
# =>: 00:17:30.612055
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 32}')
#
# <=: 00:17:30.612729
# {'response': 'ok', 'seq_num': 32}
#
#
# =>: 00:17:30.612827
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 33}')
#
# <=: 00:17:30.613484
# {'response': 'ok', 'seq_num': 33}
#
#
# =>: 00:17:30.613582
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 34}')
#
# <=: 00:17:30.614238
# {'response': 'ok', 'seq_num': 34}
#
#
# =>: 00:17:30.614599
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 35}')
#
# <=: 00:17:30.615050
# {'response': 'ok', 'seq_num': 35}
#
#
# =>: 00:17:30.615155
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 36}')
#
# <=: 00:17:30.615836
# {'response': 'ok', 'seq_num': 36}
#
#
# =>: 00:17:30.615940
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 37}')
#
# <=: 00:17:30.616723
# {'response': 'ok', 'seq_num': 37}
#
#
# =>: 00:17:30.616827
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 38}')
#
# <=: 00:17:30.617540
# {'response': 'ok', 'seq_num': 38}
#
#
# =>: 00:17:30.617644
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 39}')
#
# <=: 00:17:30.618322
# {'response': 'ok', 'seq_num': 39}
#
#
# =>: 00:17:30.618427
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 40}')
#
# <=: 00:17:30.619083
# {'response': 'ok', 'seq_num': 40}
#
#
# =>: 00:17:30.619192
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 41}')
#
# <=: 00:17:30.619827
# {'response': 'ok', 'seq_num': 41}
#
#
# =>: 00:17:30.619933
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 42}')
#
# <=: 00:17:30.620587
# {'response': 'ok', 'seq_num': 42}
#
#
# =>: 00:17:30.620693
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 43}')
#
# <=: 00:17:30.621448
# {'response': 'ok', 'seq_num': 43}
#
#
# =>: 00:17:30.621554
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 44}')
#
# <=: 00:17:30.622274
# {'response': 'ok', 'seq_num': 44}
#
#
# =>: 00:17:30.622379
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 45}')
#
# <=: 00:17:30.623082
# {'response': 'ok', 'seq_num': 45}
#
#
# =>: 00:17:30.623189
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 46}')
#
# <=: 00:17:30.624055
# {'response': 'ok', 'seq_num': 46}
#
#
# =>: 00:17:30.624359
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 47}')
#
# <=: 00:17:30.624818
# {'response': 'ok', 'seq_num': 47}
#
#
# =>: 00:17:30.624923
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 48}')
#
# <=: 00:17:30.625659
# {'response': 'ok', 'seq_num': 48}
#
#
# =>: 00:17:30.625769
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 49}')
#
# <=: 00:17:30.626435
# {'response': 'ok', 'seq_num': 49}
#
#
# =>: 00:17:30.626561
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 50}')
#
# <=: 00:17:30.627361
# {'response': 'ok', 'seq_num': 50}
#
#
# =>: 00:17:30.627473
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 51}')
#
# <=: 00:17:30.628153
# {'response': 'ok', 'seq_num': 51}
#
#
# =>: 00:17:30.628264
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 52}')
#
# <=: 00:17:30.629073
# {'response': 'ok', 'seq_num': 52}
#
#
# =>: 00:17:30.629183
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 53}')
#
# <=: 00:17:30.629870
# {'response': 'ok', 'seq_num': 53}
#
#
# =>: 00:17:30.629981
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 54}')
#
# <=: 00:17:30.630716
# {'response': 'ok', 'seq_num': 54}
#
#
# =>: 00:17:30.630827
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 55}')
#
# <=: 00:17:30.631586
# {'response': 'ok', 'seq_num': 55}
#
#
# =>: 00:17:30.631698
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 56}')
#
# <=: 00:17:30.632373
# {'response': 'ok', 'seq_num': 56}
#
#
# =>: 00:17:30.632483
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 57}')
#
# <=: 00:17:30.633240
# {'response': 'ok', 'seq_num': 57}
#
#
# =>: 00:17:30.633350
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 58}')
#
# <=: 00:17:30.634031
# {'response': 'ok', 'seq_num': 58}
#
#
# =>: 00:17:30.634141
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 59}')
#
# <=: 00:17:30.634793
# {'response': 'ok', 'seq_num': 59}
#
#
# =>: 00:17:30.634906
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 60}')
#
# <=: 00:17:30.635557
# {'response': 'ok', 'seq_num': 60}
#
#
# =>: 00:17:30.635897
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 61}')
#
# <=: 00:17:30.636347
# {'response': 'ok', 'seq_num': 61}
#
#
# =>: 00:17:30.636457
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 62}')
#
# <=: 00:17:30.637133
# {'response': 'ok', 'seq_num': 62}
#
#
# =>: 00:17:30.637243
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 63}')
#
# <=: 00:17:30.637901
# {'response': 'ok', 'seq_num': 63}
#
#
# =>: 00:17:30.638014
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 64}')
#
# <=: 00:17:30.638669
# {'response': 'ok', 'seq_num': 64}
#
#
# =>: 00:17:30.638985
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 65}')
#
# <=: 00:17:30.639458
# {'response': 'ok', 'seq_num': 65}
#
#
# =>: 00:17:30.639568
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 66}')
#
# <=: 00:17:30.640246
# {'response': 'ok', 'seq_num': 66}
#
#
# =>: 00:17:30.640366
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 67}')
#
# <=: 00:17:30.641102
# {'response': 'ok', 'seq_num': 67}
#
#
# =>: 00:17:30.641209
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 68}')
#
# <=: 00:17:30.641886
# {'response': 'ok', 'seq_num': 68}
#
#
# =>: 00:17:30.641999
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 69}')
#
# <=: 00:17:30.642639
# {'response': 'ok', 'seq_num': 69}
#
#
# =>: 00:17:30.642748
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 70}')
#
# <=: 00:17:30.643378
# {'response': 'ok', 'seq_num': 70}
#
#
# =>: 00:17:30.643486
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 71}')
#
# <=: 00:17:30.644151
# {'response': 'ok', 'seq_num': 71}
#
#
# =>: 00:17:30.644257
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 72}')
#
# <=: 00:17:30.645044
# {'response': 'ok', 'seq_num': 72}
#
#
# =>: 00:17:30.645150
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 73}')
#
# <=: 00:17:30.645822
# {'response': 'ok', 'seq_num': 73}
#
#
# =>: 00:17:30.645929
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 74}')
#
# <=: 00:17:30.646714
# {'response': 'ok', 'seq_num': 74}
#
#
# =>: 00:17:30.646825
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 75}')
#
# <=: 00:17:30.647537
# {'response': 'ok', 'seq_num': 75}
#
#
# =>: 00:17:30.647645
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 76}')
#
# <=: 00:17:30.648295
# {'response': 'ok', 'seq_num': 76}
#
#
# =>: 00:17:30.648403
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 77}')
#
# <=: 00:17:30.649034
# {'response': 'ok', 'seq_num': 77}
#
#
# =>: 00:17:30.649147
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 78}')
#
# <=: 00:17:30.649789
# {'response': 'ok', 'seq_num': 78}
#
#
# =>: 00:17:30.650121
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 79}')
#
# <=: 00:17:30.650568
# {'response': 'ok', 'seq_num': 79}
#
#
# =>: 00:17:30.650675
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 80}')
#
# <=: 00:17:30.651338
# {'response': 'ok', 'seq_num': 80}
#
#
# =>: 00:17:30.651454
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 81}')
#
# <=: 00:17:30.652089
# {'response': 'ok', 'seq_num': 81}
#
#
# =>: 00:17:30.652198
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 82}')
#
# <=: 00:17:30.652837
# {'response': 'ok', 'seq_num': 82}
#
#
# =>: 00:17:30.653167
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 83}')
#
# <=: 00:17:30.653617
# {'response': 'ok', 'seq_num': 83}
#
#
# =>: 00:17:30.653724
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 84}')
#
# <=: 00:17:30.654461
# {'response': 'ok', 'seq_num': 84}
#
#
# =>: 00:17:30.654576
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 85}')
#
# <=: 00:17:30.655245
# {'response': 'ok', 'seq_num': 85}
#
#
# =>: 00:17:30.655353
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 86}')
#
# <=: 00:17:30.655997
# {'response': 'ok', 'seq_num': 86}
#
#
# =>: 00:17:30.656106
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 87}')
#
# <=: 00:17:30.656743
# {'response': 'ok', 'seq_num': 87}
#
#
# =>: 00:17:30.656850
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 88}')
#
# <=: 00:17:30.657517
# {'response': 'ok', 'seq_num': 88}
#
#
# =>: 00:17:30.657625
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 89}')
#
# <=: 00:17:30.658387
# {'response': 'ok', 'seq_num': 89}
#
#
# =>: 00:17:30.658496
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 90}')
#
# <=: 00:17:30.659217
# {'response': 'ok', 'seq_num': 90}
#
#
# =>: 00:17:30.659326
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 91}')
#
# <=: 00:17:30.659985
# {'response': 'ok', 'seq_num': 91}
#
#
# =>: 00:17:30.660092
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 92}')
#
# <=: 00:17:30.660727
# {'response': 'ok', 'seq_num': 92}
#
#
# =>: 00:17:30.660835
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 93}')
#
# <=: 00:17:30.661479
# {'response': 'ok', 'seq_num': 93}
#
#
# =>: 00:17:30.661809
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 94}')
#
# <=: 00:17:30.662250
# {'response': 'ok', 'seq_num': 94}
#
#
# =>: 00:17:30.662357
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 95}')
#
# <=: 00:17:30.663106
# {'response': 'ok', 'seq_num': 95}
#
#
# =>: 00:17:30.663216
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 96}')
#
# <=: 00:17:30.663947
# {'response': 'ok', 'seq_num': 96}
#
#
# =>: 00:17:30.664054
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 97}')
#
# <=: 00:17:30.664716
# {'response': 'ok', 'seq_num': 97}
#
#
# =>: 00:17:30.664824
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 98}')
#
# <=: 00:17:30.665470
# {'response': 'ok', 'seq_num': 98}
#
#
# =>: 00:17:30.665578
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 99}')
#
# <=: 00:17:30.666212
# {'response': 'ok', 'seq_num': 99}
#
#
# =>: 00:17:30.666320
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 100}')
#
# <=: 00:17:30.666983
# {'response': 'ok', 'seq_num': 100}
#
#
# =>: 00:17:30.667091
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 101}')
#
# <=: 00:17:30.667874
# {'response': 'ok', 'seq_num': 101}
#
#
# =>: 00:17:30.667981
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 102}')
#
# <=: 00:17:30.668689
# {'response': 'ok', 'seq_num': 102}
#
#
# =>: 00:17:30.668797
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 103}')
#
# <=: 00:17:30.669463
# {'response': 'ok', 'seq_num': 103}
#
#
# =>: 00:17:30.669569
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 104}')
#
# <=: 00:17:30.670210
# {'response': 'ok', 'seq_num': 104}
#
#
# =>: 00:17:30.670319
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 105}')
#
# <=: 00:17:30.670965
# {'response': 'ok', 'seq_num': 105}
#
#
# =>: 00:17:30.671296
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 106}')
#
# <=: 00:17:30.671740
# {'response': 'ok', 'seq_num': 106}
#
#
# =>: 00:17:30.671847
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 107}')
#
# <=: 00:17:30.672587
# {'response': 'ok', 'seq_num': 107}
#
#
# =>: 00:17:30.672693
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 108}')
#
# <=: 00:17:30.673389
# {'response': 'ok', 'seq_num': 108}
#
#
# =>: 00:17:30.673496
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 109}')
#
# <=: 00:17:30.674278
# {'response': 'ok', 'seq_num': 109}
#
#
# =>: 00:17:30.674385
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 110}')
#
# <=: 00:17:30.675131
# {'response': 'ok', 'seq_num': 110}
#
#
# =>: 00:17:30.675241
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 111}')
#
# <=: 00:17:30.675941
# {'response': 'ok', 'seq_num': 111}
#
#
# =>: 00:17:30.676052
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 112}')
#
# <=: 00:17:30.676806
# {'response': 'ok', 'seq_num': 112}
#
#
# =>: 00:17:30.676916
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 113}')
#
# <=: 00:17:30.677679
# {'response': 'ok', 'seq_num': 113}
#
#
# =>: 00:17:30.677789
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 114}')
#
# <=: 00:17:30.678487
# {'response': 'ok', 'seq_num': 114}
#
#
# =>: 00:17:30.678616
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 115}')
#
# <=: 00:17:30.679327
# {'response': 'ok', 'seq_num': 115}
#
#
# =>: 00:17:30.679439
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 116}')
#
# <=: 00:17:30.680299
# {'response': 'ok', 'seq_num': 116}
#
#
# =>: 00:17:30.680612
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 117}')
#
# <=: 00:17:30.681078
# {'response': 'ok', 'seq_num': 117}
#
#
# =>: 00:17:30.681188
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 118}')
#
# <=: 00:17:30.681903
# {'response': 'ok', 'seq_num': 118}
#
#
# =>: 00:17:30.682013
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 119}')
#
# <=: 00:17:30.682733
# {'response': 'ok', 'seq_num': 119}
#
#
# =>: 00:17:30.682844
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 120}')
#
# <=: 00:17:30.683526
# {'response': 'ok', 'seq_num': 120}
#
#
# =>: 00:17:30.683637
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 121}')
#
# <=: 00:17:30.684281
# {'response': 'ok', 'seq_num': 121}
#
#
# =>: 00:17:30.684393
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 122}')
#
# <=: 00:17:30.685034
# {'response': 'ok', 'seq_num': 122}
#
#
# =>: 00:17:30.685365
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 123}')
#
# <=: 00:17:30.685824
# {'response': 'ok', 'seq_num': 123}
#
#
# =>: 00:17:30.685933
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 124}')
#
# <=: 00:17:30.686708
# {'response': 'ok', 'seq_num': 124}
#
#
# =>: 00:17:30.686826
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 125}')
#
# <=: 00:17:30.687498
# {'response': 'ok', 'seq_num': 125}
#
#
# =>: 00:17:30.687609
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 126}')
#
# <=: 00:17:30.688280
# {'response': 'ok', 'seq_num': 126}
#
#
# =>: 00:17:30.688389
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 127}')
#
# <=: 00:17:30.689037
# {'response': 'ok', 'seq_num': 127}
#
#
# =>: 00:17:30.689148
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 128}')
#
# <=: 00:17:30.689801
# {'response': 'ok', 'seq_num': 128}
#
#
# =>: 00:17:30.690022
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 129}')
#
# <=: 00:17:30.690581
# {'response': 'ok', 'seq_num': 129}
#
#
# =>: 00:17:30.690692
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 130}')
#
# <=: 00:17:30.691441
# {'response': 'ok', 'seq_num': 130}
#
#
# =>: 00:17:30.691552
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 131}')
#
# <=: 00:17:30.692321
# {'response': 'ok', 'seq_num': 131}
#
#
# =>: 00:17:30.692769
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 132}')
#
# <=: 00:17:30.693500
# {'response': 'ok', 'seq_num': 132}
#
#
# =>: 00:17:30.693624
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 133}')
#
# <=: 00:17:30.694266
# {'response': 'ok', 'seq_num': 133}
#
#
# =>: 00:17:30.694362
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 134}')
#
# <=: 00:17:30.695021
# {'response': 'ok', 'seq_num': 134}
#
#
# =>: 00:17:30.695115
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 135}')
#
# <=: 00:17:30.695797
# {'response': 'ok', 'seq_num': 135}
#
#
# =>: 00:17:30.696066
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 136}')
#
# <=: 00:17:30.696893
# {'response': 'ok', 'seq_num': 136}
#
#
# =>: 00:17:30.697129
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 137}')
#
# <=: 00:17:30.697942
# {'response': 'ok', 'seq_num': 137}
#
#
# =>: 00:17:30.698170
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 138}')
#
# <=: 00:17:30.699050
# {'response': 'ok', 'seq_num': 138}
#
#
# =>: 00:17:30.699302
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 139}')
#
# <=: 00:17:30.700151
# {'response': 'ok', 'seq_num': 139}
#
#
# =>: 00:17:30.700748
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 140}')
#
# <=: 00:17:30.701428
# {'response': 'ok', 'seq_num': 140}
#
#
# =>: 00:17:30.701661
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 141}')
#
# <=: 00:17:30.702495
# {'response': 'ok', 'seq_num': 141}
#
#
# =>: 00:17:30.702739
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 142}')
#
# <=: 00:17:30.703565
# {'response': 'ok', 'seq_num': 142}
#
#
# =>: 00:17:30.703795
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 143}')
#
# <=: 00:17:30.704630
# {'response': 'ok', 'seq_num': 143}
#
#
# =>: 00:17:30.704858
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 144}')
#
# <=: 00:17:30.705667
# {'response': 'ok', 'seq_num': 144}
#
#
# =>: 00:17:30.705891
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 145}')
#
# <=: 00:17:30.706700
# {'response': 'ok', 'seq_num': 145}
#
#
# =>: 00:17:30.706793
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 146}')
#
# <=: 00:17:30.707412
# {'response': 'ok', 'seq_num': 146}
#
#
# =>: 00:17:30.707504
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 147}')
#
# <=: 00:17:30.708187
# {'response': 'ok', 'seq_num': 147}
#
#
# =>: 00:17:30.708278
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 148}')
#
# <=: 00:17:30.708946
# {'response': 'ok', 'seq_num': 148}
#
#
# =>: 00:17:30.709040
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 149}')
#
# <=: 00:17:30.709709
# {'response': 'ok', 'seq_num': 149}
#
#
# =>: 00:17:30.710050
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 150}')
#
# <=: 00:17:30.710511
# {'response': 'ok', 'seq_num': 150}
#
#
# =>: 00:17:30.710610
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 151}')
#
# <=: 00:17:30.711291
# {'response': 'ok', 'seq_num': 151}
#
#
# =>: 00:17:30.711397
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 152}')
#
# <=: 00:17:30.712133
# {'response': 'ok', 'seq_num': 152}
#
#
# =>: 00:17:30.712238
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 153}')
#
# <=: 00:17:30.712979
# {'response': 'ok', 'seq_num': 153}
#
#
# =>: 00:17:30.713084
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 154}')
#
# <=: 00:17:30.713934
# {'response': 'ok', 'seq_num': 154}
#
#
# =>: 00:17:30.714032
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 155}')
#
# <=: 00:17:30.714789
# {'response': 'ok', 'seq_num': 155}
#
#
# =>: 00:17:30.715061
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 156}')
#
# <=: 00:17:30.715615
# {'response': 'ok', 'seq_num': 156}
#
#
# =>: 00:17:30.715711
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 157}')
#
# <=: 00:17:30.716396
# {'response': 'ok', 'seq_num': 157}
#
#
# =>: 00:17:30.716498
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 158}')
#
# <=: 00:17:30.717224
# {'response': 'ok', 'seq_num': 158}
#
#
# =>: 00:17:30.717343
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 159}')
#
# <=: 00:17:30.718061
# {'response': 'ok', 'seq_num': 159}
#
#
# =>: 00:17:30.718171
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 160}')
#
# <=: 00:17:30.718906
# {'response': 'ok', 'seq_num': 160}
#
#
# =>: 00:17:30.719016
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 161}')
#
# <=: 00:17:30.719692
# {'response': 'ok', 'seq_num': 161}
#
#
# =>: 00:17:30.719801
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 162}')
#
# <=: 00:17:30.720484
# {'response': 'ok', 'seq_num': 162}
#
#
# =>: 00:17:30.720620
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 163}')
#
# <=: 00:17:30.721360
# {'response': 'ok', 'seq_num': 163}
#
#
# =>: 00:17:30.721480
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 164}')
#
# <=: 00:17:30.722201
# {'response': 'ok', 'seq_num': 164}
#
#
# =>: 00:17:30.722319
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 165}')
#
# <=: 00:17:30.723031
# {'response': 'ok', 'seq_num': 165}
#
#
# =>: 00:17:30.723141
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 166}')
#
# <=: 00:17:30.723858
# {'response': 'ok', 'seq_num': 166}
#
#
# =>: 00:17:30.723976
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 167}')
#
# <=: 00:17:30.724701
# {'response': 'ok', 'seq_num': 167}
#
#
# =>: 00:17:30.724819
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 168}')
#
# <=: 00:17:30.725525
# {'response': 'ok', 'seq_num': 168}
#
#
# =>: 00:17:30.725643
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 169}')
#
# <=: 00:17:30.726464
# {'response': 'ok', 'seq_num': 169}
#
#
# =>: 00:17:30.726831
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 170}')
#
# <=: 00:17:30.727319
# {'response': 'ok', 'seq_num': 170}
#
#
# =>: 00:17:30.727431
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 171}')
#
# <=: 00:17:30.728115
# {'response': 'ok', 'seq_num': 171}
#
#
# =>: 00:17:30.728225
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 172}')
#
# <=: 00:17:30.728906
# {'response': 'ok', 'seq_num': 172}
#
#
# =>: 00:17:30.729017
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 173}')
#
# <=: 00:17:30.729819
# {'response': 'ok', 'seq_num': 173}
#
#
# =>: 00:17:30.729941
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 174}')
#
# <=: 00:17:30.730655
# {'response': 'ok', 'seq_num': 174}
#
#
# =>: 00:17:30.730771
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 175}')
#
# <=: 00:17:30.731472
# {'response': 'ok', 'seq_num': 175}
#
#
# =>: 00:17:30.731583
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 176}')
#
# <=: 00:17:30.732291
# {'response': 'ok', 'seq_num': 176}
#
#
# =>: 00:17:30.732401
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 177}')
#
# <=: 00:17:30.733152
# {'response': 'ok', 'seq_num': 177}
#
#
# =>: 00:17:30.733260
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 178}')
#
# <=: 00:17:30.733931
# {'response': 'ok', 'seq_num': 178}
#
#
# =>: 00:17:30.734048
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 179}')
#
# <=: 00:17:30.734704
# {'response': 'ok', 'seq_num': 179}
#
#
# =>: 00:17:30.734818
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 180}')
#
# <=: 00:17:30.735459
# {'response': 'ok', 'seq_num': 180}
#
#
# =>: 00:17:30.735795
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 181}')
#
# <=: 00:17:30.736254
# {'response': 'ok', 'seq_num': 181}
#
#
# =>: 00:17:30.736364
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 182}')
#
# <=: 00:17:30.737044
# {'response': 'ok', 'seq_num': 182}
#
#
# =>: 00:17:30.737154
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 183}')
#
# <=: 00:17:30.737801
# {'response': 'ok', 'seq_num': 183}
#
#
# =>: 00:17:30.737922
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 184}')
#
# <=: 00:17:30.738585
# {'response': 'ok', 'seq_num': 184}
#
#
# =>: 00:17:30.738852
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 185}')
#
# <=: 00:17:30.739368
# {'response': 'ok', 'seq_num': 185}
#
#
# =>: 00:17:30.739480
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 186}')
#
# <=: 00:17:30.740150
# {'response': 'ok', 'seq_num': 186}
#
#
# =>: 00:17:30.740264
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 187}')
#
# <=: 00:17:30.740943
# {'response': 'ok', 'seq_num': 187}
#
#
# =>: 00:17:30.741052
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 188}')
#
# <=: 00:17:30.741690
# {'response': 'ok', 'seq_num': 188}
#
#
# =>: 00:17:30.741801
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 189}')
#
# <=: 00:17:30.742441
# {'response': 'ok', 'seq_num': 189}
#
#
# =>: 00:17:30.742790
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 190}')
#
# <=: 00:17:30.743239
# {'response': 'ok', 'seq_num': 190}
#
#
# =>: 00:17:30.743365
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 191}')
#
# <=: 00:17:30.744065
# {'response': 'ok', 'seq_num': 191}
#
#
# =>: 00:17:30.744236
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 192}')
#
# <=: 00:17:30.745041
# {'response': 'ok', 'seq_num': 192}
#
#
# =>: 00:17:30.745328
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 193}')
#
# <=: 00:17:30.746040
# {'response': 'ok', 'seq_num': 193}
#
#
# =>: 00:17:30.746174
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 194}')
#
# <=: 00:17:30.746826
# {'response': 'ok', 'seq_num': 194}
#
#
# =>: 00:17:30.747097
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 195}')
#
# <=: 00:17:30.747614
# {'response': 'ok', 'seq_num': 195}
#
#
# =>: 00:17:30.747725
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 196}')
#
# <=: 00:17:30.748390
# {'response': 'ok', 'seq_num': 196}
#
#
# =>: 00:17:30.748500
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 197}')
#
# <=: 00:17:30.749181
# {'response': 'ok', 'seq_num': 197}
#
#
# =>: 00:17:30.749290
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 198}')
#
# <=: 00:17:30.749938
# {'response': 'ok', 'seq_num': 198}
#
#
# =>: 00:17:30.750049
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 199}')
#
# <=: 00:17:30.750695
# {'response': 'ok', 'seq_num': 199}
#
#
# =>: 00:17:30.751034
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 200}')
#
# <=: 00:17:30.751495
# {'response': 'ok', 'seq_num': 200}
#
#
# =>: 00:17:30.751597
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 201}')
#
# <=: 00:17:30.752248
# {'response': 'ok', 'seq_num': 201}
#
#
# =>: 00:17:30.752352
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 202}')
#
# <=: 00:17:30.752973
# {'response': 'ok', 'seq_num': 202}
#
#
# =>: 00:17:30.753075
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 203}')
#
# <=: 00:17:30.753721
# {'response': 'ok', 'seq_num': 203}
#
#
# =>: 00:17:30.753824
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 204}')
#
# <=: 00:17:30.754484
# {'response': 'ok', 'seq_num': 204}
#
#
# =>: 00:17:30.754601
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 205}')
#
# <=: 00:17:30.755276
# {'response': 'ok', 'seq_num': 205}
#
#
# =>: 00:17:30.755388
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 206}')
#
# <=: 00:17:30.756026
# {'response': 'ok', 'seq_num': 206}
#
#
# =>: 00:17:30.756132
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 207}')
#
# <=: 00:17:30.756765
# {'response': 'ok', 'seq_num': 207}
#
#
# =>: 00:17:30.756869
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 208}')
#
# <=: 00:17:30.757528
# {'response': 'ok', 'seq_num': 208}
#
#
# =>: 00:17:30.757631
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 209}')
#
# <=: 00:17:30.758354
# {'response': 'ok', 'seq_num': 209}
#
#
# =>: 00:17:30.758455
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 210}')
#
# <=: 00:17:30.759162
# {'response': 'ok', 'seq_num': 210}
#
#
# =>: 00:17:30.759274
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 211}')
#
# <=: 00:17:30.759912
# {'response': 'ok', 'seq_num': 211}
#
#
# =>: 00:17:30.760017
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 212}')
#
# <=: 00:17:30.763272
# {'response': 'ok', 'seq_num': 212}
#
#
# =>: 00:17:30.763368
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 213}')
#
# <=: 00:17:30.763648
# {'response': 'ok', 'seq_num': 213}
#
#
# =>: 00:17:30.763752
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 214}')
#
# <=: 00:17:30.765025
# {'response': 'ok', 'seq_num': 214}
#
#
# =>: 00:17:30.765263
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 215}')
#
# <=: 00:17:30.766037
# {'response': 'ok', 'seq_num': 215}
#
#
# =>: 00:17:30.766256
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 216}')
#
# <=: 00:17:30.767059
# {'response': 'ok', 'seq_num': 216}
#
#
# =>: 00:17:30.767296
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 217}')
#
# <=: 00:17:30.768080
# {'response': 'ok', 'seq_num': 217}
#
#
# =>: 00:17:30.768305
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 218}')
#
# <=: 00:17:30.769069
# {'response': 'ok', 'seq_num': 218}
#
#
# =>: 00:17:30.769240
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 219}')
#
# <=: 00:17:30.769928
# {'response': 'ok', 'seq_num': 219}
#
#
# =>: 00:17:30.770060
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 220}')
#
# <=: 00:17:30.770731
# {'response': 'ok', 'seq_num': 220}
#
#
# =>: 00:17:30.771012
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 221}')
#
# <=: 00:17:30.771547
# {'response': 'ok', 'seq_num': 221}
#
#
# =>: 00:17:30.771894
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 222}')
#
# <=: 00:17:30.772354
# {'response': 'ok', 'seq_num': 222}
#
#
# =>: 00:17:30.772473
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 223}')
#
# <=: 00:17:30.773161
# {'response': 'ok', 'seq_num': 223}
#
#
# =>: 00:17:30.773279
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 224}')
#
# <=: 00:17:30.773957
# {'response': 'ok', 'seq_num': 224}
#
#
# =>: 00:17:30.774096
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 225}')
#
# <=: 00:17:30.774812
# {'response': 'ok', 'seq_num': 225}
#
#
# =>: 00:17:30.774913
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 226}')
#
# <=: 00:17:30.775549
# {'response': 'ok', 'seq_num': 226}
#
#
# =>: 00:17:30.775649
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 227}')
#
# <=: 00:17:30.776279
# {'response': 'ok', 'seq_num': 227}
#
#
# =>: 00:17:30.776378
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 228}')
#
# <=: 00:17:30.777041
# {'response': 'ok', 'seq_num': 228}
#
#
# =>: 00:17:30.777140
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 229}')
#
# <=: 00:17:30.777767
# {'response': 'ok', 'seq_num': 229}
#
#
# =>: 00:17:30.777866
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 230}')
#
# <=: 00:17:30.778498
# {'response': 'ok', 'seq_num': 230}
#
#
# =>: 00:17:30.778603
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 231}')
#
# <=: 00:17:30.779267
# {'response': 'ok', 'seq_num': 231}
#
#
# =>: 00:17:30.779365
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 232}')
#
# <=: 00:17:30.780146
# {'response': 'ok', 'seq_num': 232}
#
#
# =>: 00:17:30.780244
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 233}')
#
# <=: 00:17:30.780908
# {'response': 'ok', 'seq_num': 233}
#
#
# =>: 00:17:30.781007
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 234}')
#
# <=: 00:17:30.781351
# {'response': 'ok', 'seq_num': 234}
#
#
# =>: 00:17:30.781784
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 235}')
#
# <=: 00:17:30.782387
# {'response': 'ok', 'seq_num': 235}
#
#
# =>: 00:17:30.782485
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 236}')
#
# <=: 00:17:30.783126
# {'response': 'ok', 'seq_num': 236}
#
#
# =>: 00:17:30.783225
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 237}')
#
# <=: 00:17:30.783886
# {'response': 'ok', 'seq_num': 237}
#
#
# =>: 00:17:30.783984
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 238}')
#
# <=: 00:17:30.784779
# {'response': 'ok', 'seq_num': 238}
#
#
# =>: 00:17:30.784879
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 239}')
#
# <=: 00:17:30.785554
# {'response': 'ok', 'seq_num': 239}
#
#
# =>: 00:17:30.785653
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 240}')
#
# <=: 00:17:30.786313
# {'response': 'ok', 'seq_num': 240}
#
#
# =>: 00:17:30.786422
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 241}')
#
# <=: 00:17:30.787083
# {'response': 'ok', 'seq_num': 241}
#
#
# =>: 00:17:30.787404
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 242}')
#
# <=: 00:17:30.787892
# {'response': 'ok', 'seq_num': 242}
#
#
# =>: 00:17:30.788000
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 243}')
#
# <=: 00:17:30.788699
# {'response': 'ok', 'seq_num': 243}
#
#
# =>: 00:17:30.788812
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 244}')
#
# <=: 00:17:30.789520
# {'response': 'ok', 'seq_num': 244}
#
#
# =>: 00:17:30.789639
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 245}')
#
# <=: 00:17:30.790332
# {'response': 'ok', 'seq_num': 245}
#
#
# =>: 00:17:30.790444
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 246}')
#
# <=: 00:17:30.791114
# {'response': 'ok', 'seq_num': 246}
#
#
# =>: 00:17:30.791230
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 247}')
#
# <=: 00:17:30.791886
# {'response': 'ok', 'seq_num': 247}
#
#
# =>: 00:17:30.792214
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 248}')
#
# <=: 00:17:30.792699
# {'response': 'ok', 'seq_num': 248}
#
#
# =>: 00:17:30.793061
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 249}')
#
# <=: 00:17:30.793525
# {'response': 'ok', 'seq_num': 249}
#
#
# =>: 00:17:30.793639
# ...
#  '"seq_num": 270}')
#
# <=: 00:17:30.811254
# {'response': 'ok', 'seq_num': 270}
#
#
# =>: 00:17:30.811373
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 271}')
#
# <=: 00:17:30.812091
# {'response': 'ok', 'seq_num': 271}
#
#
# =>: 00:17:30.812208
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 272}')
#
# <=: 00:17:30.812949
# {'response': 'ok', 'seq_num': 272}
#
#
# =>: 00:17:30.813067
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 273}')
#
# <=: 00:17:30.813794
# {'response': 'ok', 'seq_num': 273}
#
#
# =>: 00:17:30.813912
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 274}')
#
# <=: 00:17:30.814654
# {'response': 'ok', 'seq_num': 274}
#
#
# =>: 00:17:30.814773
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 275}')
#
# <=: 00:17:30.815493
# {'response': 'ok', 'seq_num': 275}
#
#
# =>: 00:17:30.815611
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 276}')
#
# <=: 00:17:30.816351
# {'response': 'ok', 'seq_num': 276}
#
#
# =>: 00:17:30.816470
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 277}')
#
# <=: 00:17:30.817187
# {'response': 'ok', 'seq_num': 277}
#
#
# =>: 00:17:30.817305
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 278}')
#
# <=: 00:17:30.818071
# {'response': 'ok', 'seq_num': 278}
#
#
# =>: 00:17:30.818190
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 279}')
#
# <=: 00:17:30.818927
# {'response': 'ok', 'seq_num': 279}
#
#
# =>: 00:17:30.819044
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 280}')
#
# <=: 00:17:30.819769
# {'response': 'ok', 'seq_num': 280}
#
#
# =>: 00:17:30.819887
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 281}')
#
# <=: 00:17:30.820613
# {'response': 'ok', 'seq_num': 281}
#
#
# =>: 00:17:30.820726
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 282}')
#
# <=: 00:17:30.821451
# {'response': 'ok', 'seq_num': 282}
#
#
# =>: 00:17:30.821565
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 283}')
#
# <=: 00:17:30.822283
# {'response': 'ok', 'seq_num': 283}
#
#
# =>: 00:17:30.822397
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 284}')
#
# <=: 00:17:30.823124
# {'response': 'ok', 'seq_num': 284}
#
#
# =>: 00:17:30.823238
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 285}')
#
# <=: 00:17:30.823954
# {'response': 'ok', 'seq_num': 285}
#
#
# =>: 00:17:30.824070
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 286}')
#
# <=: 00:17:30.824790
# {'response': 'ok', 'seq_num': 286}
#
#
# =>: 00:17:30.824904
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 287}')
#
# <=: 00:17:30.825620
# {'response': 'ok', 'seq_num': 287}
#
#
# =>: 00:17:30.825734
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 288}')
#
# <=: 00:17:30.826506
# {'response': 'ok', 'seq_num': 288}
#
#
# =>: 00:17:30.826628
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 289}')
#
# <=: 00:17:30.827351
# {'response': 'ok', 'seq_num': 289}
#
#
# =>: 00:17:30.827466
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 290}')
#
# <=: 00:17:30.828184
# {'response': 'ok', 'seq_num': 290}
#
#
# =>: 00:17:30.828298
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 291}')
#
# <=: 00:17:30.829014
# {'response': 'ok', 'seq_num': 291}
#
#
# =>: 00:17:30.829128
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 292}')
#
# <=: 00:17:30.829852
# {'response': 'ok', 'seq_num': 292}
#
#
# =>: 00:17:30.829967
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 293}')
#
# <=: 00:17:30.830693
# {'response': 'ok', 'seq_num': 293}
#
#
# =>: 00:17:30.830809
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 294}')
#
# <=: 00:17:30.831537
# {'response': 'ok', 'seq_num': 294}
#
#
# =>: 00:17:30.831654
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 295}')
#
# <=: 00:17:30.832375
# {'response': 'ok', 'seq_num': 295}
#
#
# =>: 00:17:30.832494
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 296}')
#
# <=: 00:17:30.833213
# {'response': 'ok', 'seq_num': 296}
#
#
# =>: 00:17:30.833331
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 297}')
#
# <=: 00:17:30.834047
# {'response': 'ok', 'seq_num': 297}
#
#
# =>: 00:17:30.834165
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 298}')
#
# <=: 00:17:30.834892
# {'response': 'ok', 'seq_num': 298}
#
#
# =>: 00:17:30.835010
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 299}')
#
# <=: 00:17:30.835732
# {'response': 'ok', 'seq_num': 299}
#
#
# =>: 00:17:30.835850
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 300}')
#
# <=: 00:17:30.836569
# {'response': 'ok', 'seq_num': 300}
#
#
# =>: 00:17:30.836686
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 301}')
#
# <=: 00:17:30.837404
# {'response': 'ok', 'seq_num': 301}
#
#
# =>: 00:17:30.837522
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 302}')
#
# <=: 00:17:30.838243
# {'response': 'ok', 'seq_num': 302}
#
#
# =>: 00:17:30.838360
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 303}')
#
# <=: 00:17:30.839089
# {'response': 'ok', 'seq_num': 303}
#
#
# =>: 00:17:30.839206
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 304}')
#
# <=: 00:17:30.839925
# {'response': 'ok', 'seq_num': 304}
#
#
# =>: 00:17:30.840042
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 305}')
#
# <=: 00:17:30.840760
# {'response': 'ok', 'seq_num': 305}
#
#
# =>: 00:17:30.840878
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 306}')
#
# <=: 00:17:30.841597
# {'response': 'ok', 'seq_num': 306}
#
#
# =>: 00:17:30.841714
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 307}')
#
# <=: 00:17:30.842440
# {'response': 'ok', 'seq_num': 307}
#
#
# =>: 00:17:30.842561
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 308}')
#
# <=: 00:17:30.843275
# {'response': 'ok', 'seq_num': 308}
#
#
# =>: 00:17:30.843390
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 309}')
#
# <=: 00:17:30.844104
# {'response': 'ok', 'seq_num': 309}
#
#
# =>: 00:17:30.844218
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 310}')
#
# <=: 00:17:30.844931
# {'response': 'ok', 'seq_num': 310}
#
#
# =>: 00:17:30.845046
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 311}')
#
# <=: 00:17:30.845809
# {'response': 'ok', 'seq_num': 311}
#
#
# =>: 00:17:30.845921
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 312}')
#
# <=: 00:17:30.846680
# {'msgs': [{'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 70,
#            'severity': 'information',
#            'text': 'Goals: 0\n\n\n'},
#           {'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 71,
#            'severity': 'information',
#            'text': '\n'},
#           {'caption': 'eval result',
#            'end_pos_col': 7,
#            'end_pos_line': 75,
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 75,
#            'severity': 'information',
#            'text': '1'}],
#  'response': 'all_messages'}
#
# <=: 00:17:30.850589
# {'response': 'ok', 'seq_num': 312}
#
#
# =>: 00:17:30.850713
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 313}')
#
# <=: 00:17:30.851408
# {'response': 'ok', 'seq_num': 313}
#
#
# =>: 00:17:30.851637
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 314}')
#
# <=: 00:17:30.852252
# {'response': 'ok', 'seq_num': 314}
#
#
# =>: 00:17:30.852455
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 315}')
#
# <=: 00:17:30.853095
# {'response': 'ok', 'seq_num': 315}
#
#
# =>: 00:17:30.853296
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 316}')
#
# <=: 00:17:30.853933
# {'response': 'ok', 'seq_num': 316}
#
#
# =>: 00:17:30.854132
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 317}')
#
# <=: 00:17:30.854780
# {'response': 'ok', 'seq_num': 317}
#
#
# =>: 00:17:30.854981
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 318}')
#
# <=: 00:17:30.855615
# {'response': 'ok', 'seq_num': 318}
#
#
# =>: 00:17:30.855841
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 319}')
#
# <=: 00:17:30.856448
# {'response': 'ok', 'seq_num': 319}
#
#
# =>: 00:17:30.856703
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 320}')
#
# <=: 00:17:30.857282
# {'response': 'ok', 'seq_num': 320}
#
#
# =>: 00:17:30.857565
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 321}')
#
# <=: 00:17:30.858118
# {'response': 'ok', 'seq_num': 321}
#
#
# =>: 00:17:30.858400
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 322}')
#
# <=: 00:17:30.859507
# {'response': 'ok', 'seq_num': 322}
#
#
# =>: 00:17:30.859632
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 323}')
#
# <=: 00:17:30.860536
# {'response': 'ok', 'seq_num': 323}
#
#
# =>: 00:17:30.860660
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 324}')
#
# <=: 00:17:30.862352
# {'response': 'ok', 'seq_num': 324}
#
#
# =>: 00:17:30.862476
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 325}')
#
# <=: 00:17:30.863793
# {'response': 'ok', 'seq_num': 325}
#
#
# =>: 00:17:30.863918
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 326}')
#
# <=: 00:17:30.865215
# {'response': 'ok', 'seq_num': 326}
#
#
# =>: 00:17:30.865338
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 327}')
#
# <=: 00:17:30.866658
# {'response': 'ok', 'seq_num': 327}
#
#
# =>: 00:17:30.866787
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 328}')
#
# <=: 00:17:30.867965
# {'response': 'ok', 'seq_num': 328}
#
#
# =>: 00:17:30.868095
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 329}')
#
# <=: 00:17:30.869519
# {'response': 'ok', 'seq_num': 329}
#
#
# =>: 00:17:30.869650
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 330}')
#
# <=: 00:17:30.870342
# {'response': 'ok', 'seq_num': 330}
#
#
# =>: 00:17:30.870556
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 331}')
#
# <=: 00:17:30.871219
# {'response': 'ok', 'seq_num': 331}
#
#
# =>: 00:17:30.871346
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 332}')
#
# <=: 00:17:30.872055
# {'response': 'ok', 'seq_num': 332}
#
#
# =>: 00:17:30.872181
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 333}')
#
# <=: 00:17:30.872914
# {'response': 'ok', 'seq_num': 333}
#
#
# =>: 00:17:30.873042
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 334}')
#
# <=: 00:17:30.873781
# {'response': 'ok', 'seq_num': 334}
#
#
# =>: 00:17:30.873913
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 335}')
#
# <=: 00:17:30.874650
# {'response': 'ok', 'seq_num': 335}
#
#
# =>: 00:17:30.874779
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 336}')
#
# <=: 00:17:30.875510
# {'response': 'ok', 'seq_num': 336}
#
#
# =>: 00:17:30.875638
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 337}')
#
# <=: 00:17:30.876375
# {'response': 'ok', 'seq_num': 337}
#
#
# =>: 00:17:30.876507
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 338}')
#
# <=: 00:17:30.877236
# {'response': 'ok', 'seq_num': 338}
#
#
# =>: 00:17:30.877368
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 339}')
#
# <=: 00:17:30.878100
# {'response': 'ok', 'seq_num': 339}
#
#
# =>: 00:17:30.878232
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 340}')
#
# <=: 00:17:30.878974
# {'response': 'ok', 'seq_num': 340}
#
#
# =>: 00:17:30.879108
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 341}')
#
# <=: 00:17:30.879836
# {'response': 'ok', 'seq_num': 341}
#
#
# =>: 00:17:30.879969
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 342}')
#
# <=: 00:17:30.880697
# {'response': 'ok', 'seq_num': 342}
#
#
# =>: 00:17:30.880829
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 343}')
#
# <=: 00:17:30.881556
# {'response': 'ok', 'seq_num': 343}
#
#
# =>: 00:17:30.881687
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 344}')
#
# <=: 00:17:30.882420
# {'response': 'ok', 'seq_num': 344}
#
#
# =>: 00:17:30.882561
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 345}')
#
# <=: 00:17:30.883299
# {'response': 'ok', 'seq_num': 345}
#
#
# =>: 00:17:30.883432
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 346}')
#
# <=: 00:17:30.884159
# {'response': 'ok', 'seq_num': 346}
#
#
# =>: 00:17:30.884293
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 347}')
#
# <=: 00:17:30.885023
# {'response': 'ok', 'seq_num': 347}
#
#
# =>: 00:17:30.885156
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 348}')
#
# <=: 00:17:30.885945
# {'response': 'ok', 'seq_num': 348}
#
#
# =>: 00:17:30.886076
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 349}')
#
# <=: 00:17:30.886840
# {'response': 'ok', 'seq_num': 349}
#
#
# =>: 00:17:30.886972
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 350}')
#
# <=: 00:17:30.887733
# {'response': 'ok', 'seq_num': 350}
#
#
# =>: 00:17:30.887849
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 351}')
#
# <=: 00:17:30.888564
# {'response': 'ok', 'seq_num': 351}
#
#
# =>: 00:17:30.888763
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 352}')
#
# <=: 00:17:30.889415
# {'response': 'ok', 'seq_num': 352}
#
#
# =>: 00:17:30.889532
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 353}')
#
# <=: 00:17:30.890241
# {'response': 'ok', 'seq_num': 353}
#
#
# =>: 00:17:30.890439
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 354}')
#
# <=: 00:17:30.891108
# {'response': 'ok', 'seq_num': 354}
#
#
# =>: 00:17:30.891226
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 355}')
#
# <=: 00:17:30.891935
# {'response': 'ok', 'seq_num': 355}
#
#
# =>: 00:17:30.892134
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 356}')
#
# <=: 00:17:30.892793
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 00:17:30.892902
# {'response': 'ok', 'seq_num': 356}
#
#
# =>: 00:17:30.893009
# ('{"command": "info", "file_name": "dummy.lean", "column": 0, "line": 1, '
#  '"seq_num": 357}')
#
# <=: 00:17:30.893917
# {'response': 'ok', 'seq_num': 357}
# ('success', [], '')

# %%
# lots of examples
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal1, 'refl'))
    display(lean_interface.apply_tactic(goal1, 'skip'))
    display(lean_interface.apply_tactic(goal1, 'done'))
    display(lean_interface.apply_tactic(goal1, 'abc123'))
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    display(lean_interface.apply_tactic(goal2, 'induction n'))
    goal3 = LeanGoal([], [], 'abc = xyz')
    display(lean_interface.apply_tactic(goal3, 'skip'))
    display(lean_interface.apply_tactic(goal3, 'fgh'))
# Out:
# ('success', [], '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop'], conclusion='@eq.{1} Prop p p')],
#  '')
# ('tactic_failure',
#  ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#  '')
# ('tactic_failure',
#  ["unknown identifier 'abc123'",
#   "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#  '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n'], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')

# %%
# examples of executing in batch
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    goal3 = LeanGoal([], [], 'abc = xyz')
    
    goals = [goal1, goal1, goal1, goal1, goal2, goal3, goal3]
    tactics = ['refl', 'skip', 'done', 'abc123', 'induction n', 'skip', 'fgh']
    
    display(lean_interface.apply_tactic_multiple(goals, tactics))
# Out:
# [('success', [], ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop'], conclusion='@eq.{1} Prop p p')],
#   ''),
#  ('tactic_failure',
#   ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#   ''),
#  ('tactic_failure',
#   ["unknown identifier 'abc123'",
#    "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#   ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#    LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n'], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   '')]

# %% [markdown]
# ### Speed and robustness
# Unfortunately, this is quit slow.

# %%
# time it
total_runs = 50
total_time = 0
goal = LeanGoal([], [],  'true')
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(goal, 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic(goal, 'refl')
        b = time.time()
        total_time += b - a
"Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs)
# Out:
# 'Each call to the Lean interface takes on average 0.10727113723754883 seconds'

# %% [markdown]
# But sending multiple calls to Lean speeds things up.

# %%
# time running multiple goal-tactics at a time 
total_runs = 50
batch_size = 32
total_time = 0
goals = [LeanGoal([], [],  'true')] * batch_size
tactics = ['refl'] * batch_size
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(LeanGoal([], [],  'true'), 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic_multiple(goals, tactics)
        b = time.time()
        total_time += b - a
display("Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs))
display("Each goal/tactic pair (w/ batch size {}) takes on average {} seconds".format(batch_size, total_time / total_runs / batch_size))
# Out:
# 'Each call to the Lean interface takes on average 0.20561595916748046 seconds'
# 'Each goal/tactic pair (w/ batch size 32) takes on average 0.006425498723983764 seconds'

# %% [markdown]
# It is very difficult to make this process robust. If one is not careful, the results returned by `apply_tactic_multiple` could be for a previous call to the method.  There are ways to get around this, but if one is not careful they would significantly increase Lean's memory usage over time.  (For example, using a new file name for every "sync" request would be bad, since Lean caches the results of each file.)  This is a test that `apply_tactic_multiple` is robust.

# %%
# test robustness.  Make sure we are getting correct results back 
# and not results for a previous request.
rounds = 100
with LeanTacticTestingInterface() as lean_interface:
    for r in range(rounds):
        count = rounds - r
        goals = [LeanGoal([], ['p_{}_{} : Prop'.format(r, i)],  'p_{}_{}'.format(r, i)) for i in range(count)]
        
        if r % 3 == 0:
            tactics = ['skip' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, new_goals, _) in enumerate(results):
                assert response == 'success'
                assert new_goals[0].conclusion == 'p_{}_{}'.format(r, i)
        else:
            tactics = ['simp' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, _, _) in enumerate(results):
                assert response == 'tactic_failure', response
"Passed tests"
# Out:
# 'Passed tests'

# %% [markdown]
# ### Stepping through a full proof

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m nat.zero) (@has_add.add.{0} nat nat.has_add nat.zero m)'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m n_n) (@has_add.add.{0} nat nat.has_add n_n m)'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m)')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['m n_n : ℕ','n_ih : m + n_n = n_n + m'], 'm + nat.succ n_n = nat.succ n_n + m'), 
        "induction m"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero n_n) (@has_add.add.{0} nat nat.has_add n_n nat.zero)'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) nat.zero)'),
#   LeanGoal(universes=[], assumptions=['n_n : nat', 'm_n : nat', 'm_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n n_n) (@has_add.add.{0} nat nat.has_add n_n m_n) → @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m_n)', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) n_n) (@has_add.add.{0} nat nat.has_add n_n (nat.succ m_n))'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) (nat.succ m_n))')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n : ℕ','n_ih : 0 + n_n = n_n + 0'],
         '0 + nat.succ n_n = nat.succ n_n + 0'), 
        "apply nat.add_comm"))
# Out:
# ('success', [], '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n m_n : ℕ',
         'm_ih : m_n + n_n = n_n + m_n → m_n + nat.succ n_n = nat.succ n_n + m_n',
         'n_ih : nat.succ m_n + n_n = n_n + nat.succ m_n'],
         'nat.succ m_n + nat.succ n_n = nat.succ n_n + nat.succ m_n'), 
        "simp [nat.add_comm]"))
# Out:
# ('success', [], '')

# %% [markdown]
# ## Creating a simple Lean solver (with breath first search) in Python

# %% [markdown]
# Here we put all of this together to create (a non-practical) BFS prover.  Some highlights:
# - Some tactics like `apply` take a parameter.  We search the local context for all possible things to put in this parameter.  Note, we do no type checking before sending it to Lean.  The user inputs the tactic as `apply {}` to signify that something needs to be filled in from the context.
# - Our setup assumes the tactic is only applied to the first goal.  This isn't true of all tactics, so we force this by "treeifying" our proof, that is adding brackets `{ ... }` where necessary.
# - Sending multiple calls to Lean at the same time makes it much faster.  This is the only difference between the "fast" version.
# - We provide a way to verify a proof in the end (sending the whole proof as if it was a single tactic), and also walking through the proof to get information (which might be useful for machine-learning-like training).
# - This is just a proof-of-concept and not very useful in itself.

# %%
def premises_from_goal(goal):
    prems = []
    for l in goal.assumptions:
        a, _ = l.split(":")
        for v in a.strip().split(" "):
            prems.append(v)
    return prems

def tactic_applications(tactics, prems):
    tacs = []
    for t in tactics:
        if "{}" in t:
            for p in prems:
                tacs.append(t.replace("{}", p))
        else:
            tacs.append(t)
    return tacs

def treeify_proof(proof_list):
    s = ""
    goal_cnts = [1]  # open goal counts at each depth
    for tactic, new_goal_cnt in proof_list:
        while True:
            # take goals
            goal_cnt = goal_cnts.pop()

            # if no goals at this depth, end block and take off stack again
            if goal_cnt == 0:
                s += ", }"
                continue
            
            if goal_cnt == 1:
                if s: # don't put comma in front
                    s += ", "
                
            # if more than one goal, take one of them, start block and put rest back on stack
            if goal_cnt > 1:
                goal_cnts.append(goal_cnt - 1)
                s += ", { "
            
            break
            
        # apply tactic
        s += tactic
        
        # put remaining goals on stack
        goal_cnts.append(new_goal_cnt)
            
    return s 

class BreathFirstProofSearch(LeanTacticTestingInterface):
        
    def proof_search(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            for t in all_tactics:
                response, new_goals, _ = self.apply_tactic(goal, t, verbose=verbose)
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def proof_search_fast(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            
            # faster to batch process all apply_tactic calls
            results = self.apply_tactic_multiple([goal] * len(all_tactics), all_tactics, verbose=verbose)
            for t, (response, new_goals, _) in zip(all_tactics, results):
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def is_valid_proof(self, goal, proof, verbose=False):
        t = proof.replace("\n", "")  # treat proof as a single tactic
        response, goals, _ = self.apply_tactic(goal, t, verbose=verbose)
        if response == 'success' and goals == []:
            return True
        return goals
    
    def walk_through_proof(self, lean_goal, proof):
        ts = proof.replace(" {", "").replace("}, ", "").split(", ")
        goals = [lean_goal]
        for t in ts:
            goal = goals[0]
            print(" Primary Goal:  ", goal)
            print(" Tactic applied:", t)
            _, new_goals, _ = self.apply_tactic(goal, t)
            goals = new_goals + goals[1:]
            print(" New Goals: ", new_goals)
            print(" All Goals: ", goals)
            print()

# %%
def example(goal, tactics, verbose=False):
    with BreathFirstProofSearch() as bfs:
        print("Goal:", goal)
        print("Tactics:", tactics)
        print()
        start = time.time()
        proof = bfs.proof_search_fast(goal, tactics, verbose=verbose)
        end = time.time()
        print("Time to proof:", end-start, "seconds")
        print("Proof:", proof)
        print()
        print("Verified:", bfs.is_valid_proof(goal, proof, verbose=verbose))
        print()
        print("Walk through proof:")
        bfs.walk_through_proof(goal, proof)

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], 'p ∧ q → q ∧ p'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right'],
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 1.359510898590088 seconds
# Proof: intro, cases ᾰ, split, { apply ᾰ_right, }, apply ᾰ_left
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q'], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q'], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q'], conclusion='and q p')
#  Tactic applied: cases ᾰ
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='and q p')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='q')
#  Tactic applied: apply ᾰ_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_left : p', 'ᾰ_right : q'], conclusion='p')
#  Tactic applied: apply ᾰ_left
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '(p -> (q -> r)) <-> (p /\ q -> r)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 4.8155481815338135 seconds
# Proof: split, { intro, intro, cases ᾰ_1, apply ᾰ, { apply ᾰ_1_left, }, apply ᾰ_1_right, }, intro, intro, intro, apply ᾰ, split, { apply ᾰ_1, }, apply ᾰ_2
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r'], conclusion='and p q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r'], conclusion='and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r'], conclusion='and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1 : and p q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1 : and p q'], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1 : and p q'], conclusion='r')
#  Tactic applied: cases ᾰ_1
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='r')
#  Tactic applied: apply ᾰ
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='p')
#  Tactic applied: apply ᾰ_1_left
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : p → q → r', 'ᾰ_1_left : p', 'ᾰ_1_right : q'], conclusion='q')
#  Tactic applied: apply ᾰ_1_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r'], conclusion='p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r'], conclusion='p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r'], conclusion='p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p'], conclusion='q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p'], conclusion='q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p'], conclusion='q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='r')
#  Tactic applied: apply ᾰ
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='and p q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='and p q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='and p q')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='p')
#  Tactic applied: apply ᾰ_1
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : and p q → r', 'ᾰ_1 : p', 'ᾰ_2 : q'], conclusion='q')
#  Tactic applied: apply ᾰ_2
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '¬(p ↔ ¬p)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 29.420660257339478 seconds
# Proof: intro, cases ᾰ, apply ᾰ_mp, { apply ᾰ_mpr, intro, apply ᾰ_mp, { apply ᾰ, }, apply ᾰ, }, apply ᾰ_mpr, intro, apply ᾰ_mp, { apply ᾰ, }, apply ᾰ
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : iff p (not p)'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : iff p (not p)'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ : iff p (not p)'], conclusion='false')
#  Tactic applied: cases ᾰ
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='false')
#  Tactic applied: apply ᾰ_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')
#  Tactic applied: apply ᾰ_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false')
#  Tactic applied: apply ᾰ_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')
#  Tactic applied: apply ᾰ
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')
#  Tactic applied: apply ᾰ
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='p')
#  Tactic applied: apply ᾰ_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p'], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='false')
#  Tactic applied: apply ᾰ_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')
#  Tactic applied: apply ᾰ
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'ᾰ_mp : p → not p', 'ᾰ_mpr : not p → p', 'ᾰ : p'], conclusion='p')
#  Tactic applied: apply ᾰ
#  New Goals:  []
#  All Goals:  []

# %% [markdown]
# ## Custom printing of Lean expressions

# %% [markdown]
# Our `apply_tactic` will return a list of goals, using Lean's verbose pp.all format.  Hence, `m n : ℕ ⊢ m + n = n + m` is returned as `LeanGoal(['m n : nat'], "@eq.{1} nat (@has_add.add.{0} nat nat.has_add m n) (@has_add.add.{0} nat nat.has_add n m)")`.  On one hand, this is not very readable by a human.  On the other hand, it is not as machine parsable as it could be.  It is however possible to have `apply_tactic` output the goals in other formats (or print other relevant information about the goal state).
#
# For example, here we write a simple piece of code which prints the Lean goals just as Lean does.

# %%
simple_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace_state,  -- default Lean pretty printed goals
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = simple_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# 2 goals
# case nat.zero
# m : ℕ
# ⊢ m + 0 = 0 + m
#
# case nat.succ
# m n_n : ℕ,
# n_ih : m + n_n = n_n + m
# ⊢ m + n_n.succ = n_n.succ + m

# %% [markdown]
# On the other end, we may which to print the goals as expressions.  Here is  code to do that.  (It is basically the same code we are using in the LeanTacticTestingInterface above except with s-expressions instead of pp.all formatting.)

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# Goals: 2
#
# (app
#  (app (app (const eq [1]) (const nat []))
#   (app
#    (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add []))
#     (local_const 0._fresh.10.6873 m (const 1 [])))
#    (const nat.zero [])))
#  (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero []))
#   (local_const 0._fresh.10.6873 m (const 1 []))))
#
# Local Context Vars: 1
#
# (local_const 0._fresh.10.6873 m (const 1 []))
#
# (const nat [])
#
# (app
#  (app (app (const eq [1]) (const nat []))
#   (app
#    (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add []))
#     (local_const 0._fresh.10.6873 m (const 1 [])))
#    (app (const nat.succ []) (local_const 0._fresh.11.614 n_n (const 1 [])))))
#  (app
#   (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add []))
#    (app (const nat.succ []) (local_const 0._fresh.11.614 n_n (const 1 []))))
#   (local_const 0._fresh.10.6873 m (const 1 []))))
#
# Local Context Vars: 3
#
# (local_const 0._fresh.10.6873 m (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.11.614 n_n (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.11.615 n_ih (const 1 []))
#
# (app
#  (app (app (const eq [1]) (const nat []))
#   (app
#    (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add []))
#     (local_const 0._fresh.10.6873 m (const 1 [])))
#    (local_const 0._fresh.11.614 n_n (const 1 []))))
#  (app
#   (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add []))
#    (local_const 0._fresh.11.614 n_n (const 1 [])))
#   (local_const 0._fresh.10.6873 m (const 1 []))))

# %% [markdown]
# Here is code which turns each goal into a single s-expression.  The format is `(goal <intro_cnt> <expr>)` where `<expr>` is the expression and `<intro_cnt>` is the number of `intro`s one has to do on the expression to get back to the goal.  For example `m n : ℕ ⊢ m + n = n + m` is stored as `∀ m n : ℕ, m + n = n + m` so `intro_cnt` is 2 since to `intro`s are needed to reproduce `m n : ℕ ⊢ m + n = n + m`.

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt

meta def goal_to_string (g : expr) : tactic string :=
do 
  n ← tactic.revert_all,
  goal ← tactic.target,
  tactic.iterate_exactly n (do tactic.intro1, return ()),
  goal_str ← expr_to_string goal,
  let s := "(goal " ++ (to_string n) ++ " " ++ goal_str ++ ")",
  tactic.rotate_left 1,
  return s

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 let s := join "\n\n" goal_strings,
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# (goal 1 (pi m default (const nat [])
#  (app
#   (app (app (const eq [1]) (const nat []))
#    (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (const nat.zero [])))
#   (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero [])) (var 0)))))
#
# (goal 3 (pi m default (const nat [])
#  (pi n_n default (const nat [])
#   (pi n_ih default
#    (app
#     (app (app (const eq [1]) (const nat []))
#      (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 1)) (var 0)))
#     (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (var 1)))
#    (app
#     (app (app (const eq [1]) (const nat []))
#      (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 2))
#       (app (const nat.succ []) (var 1))))
#     (app
#      (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (app (const nat.succ []) (var 1)))
#      (var 2)))))))

# %% [markdown]
# See Lewis and Wu [interface between Mathematica and Lean](https://robertylewis.com/leanmm/) for an example of parsing Lean expressions into Mathematica code.)

# %% [markdown]
# ## Current issues

# %% [markdown]
# The current system relies on Leans pretty printer (with `pp.all` set to true) to output the goals which can then be fed back into Lean.  However, the pretty print (even with `pp.all` set to true) may not always output valid Lean code.  Here are some known issues:

# %% [markdown]
# ### Privately defined terms

# %% [markdown]
# This mostly comes up in proof recording, but some true theorems of Lean can't be entered into our system since they refer to privately defined terms.  However, in most cases those theorems are also marked as private (or they are automatically created theorems internal to Lean).

# %% [markdown]
# ### Term blowup

# %% [markdown]
# Because of subexpression sharing, sometimes the terms can blow up in size (usually because of type classes).  If they get too big, the pretty printer will replace parts with `…`,  making them unusable to Lean.  (Also, for some reason an expression with two `…`s will cause the lean server to stop, so we replace `…` with `_redacted_code_too_long_`.) As we can see, even the statement `12345678901234567890 - 12345678901234567890 = 0`, when expanded out, is too large for the pretty printer.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], [], '12345678901234567890 - 12345678901234567890 = 0')
    result = (lean_interface.apply_tactic(goal, "skip"))
    goal2 = result[1][0]
    print("New goal:\n", goal2)
    print()
    print("Put that new goal back in...")
    result2 = (lean_interface.apply_tactic(goal2, "skip"))
    display(result2)
# Out:
# New goal:
#  LeanGoal(universes=[], assumptions=[], conclusion='@eq.{1} nat (@has_sub.sub.{0} nat nat.has_sub (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (… nat.has_one nat.has_add (… nat.has_add (… …)))))))))))))))))))))))))))))))))))))))))))))))))))))))))))) (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0 ...
#
# Put that new goal back in...
# ('theorem_error',
#  ["unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'"],
#  '')

# %% [markdown]
# ### Missing @ symbols

# %% [markdown]
# `@` symbols are needed for some functions with implicit parameters.  With `pp.all` set to true, the pretty printer usually adds the `@` symbols as needed but can occasionally miss some cases.  Here is one such case.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], [], '@id.{u} = @id.{u}')
    result = (lean_interface.apply_tactic(goal, "skip"))
    goal2 = result[1][0]
    print("New goal:\n", goal2)
    print()
    print("Put that new goal back in...")
    result2 = (lean_interface.apply_tactic(goal2, "skip"))
    display(result2)
    goal3 = LeanGoal(['u'], [], '@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) @id.{u} @id.{u}')
    print("What the new goal should be:\n", goal3)
    print()
    print("Put that new goal back in...")
    result3 = (lean_interface.apply_tactic(goal3, "skip"))
    display(result3)
# Out:
# New goal:
#  LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) id.{u} id.{u}')
#
# Put that new goal back in...
# ('theorem_error',
#  ['type mismatch at application\n  eq id\nterm\n  id\nhas type\n  ?m_1 → ?m_1 : Sort u\nbut is expected to have type\n  Π {α : Sort u}, α → α : Sort (imax (u+1) u)'],
#  '')
# What the new goal should be:
#  LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) @id.{u} @id.{u}')
#
# Put that new goal back in...
# ('success',
#  [LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) id.{u} id.{u}')],
#  '')

# %% [markdown]
# ### Extra `@` sysmbols (or maybe a missing case in the Lean parser)

# %% [markdown]
# Currently `@(λ {α : Type} (x : α), x)` is not valid Lean code even though `@id` is.  However, the pretty printer tries to add an @ in this case (and even without the `@` it would still be incorrect, so it is likely a bug in the Lean parser).  Consider this example:
# ```lean
# theorem id_defn : @id = (λ {α : Type} (x: α), x) := by refl
# #check congr_fun id_defn bool -- @eq.{1} ((λ (x : Type), x → x) bool) (@id.{1} bool) (@(λ {α : Type} (x : α), x) bool)
# ```
# If we try plugging that theorem into Lean as follows, we will get an error:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], [], '@eq.{1} ((λ (x : Type), x → x) bool) (@id.{1} bool) (@(λ {α : Type} (x : α), x) bool)')
    result = (lean_interface.apply_tactic(goal, "skip"))
    print(result)
# Out:
# ('theorem_error', ["invalid '@', identifier expected"], '')

# %% [markdown]
# ### Implicit and type class assumptions

# %% [markdown]
# One can't directly enter typeclass and implicit assumptions into our framework.  We could easily add this functionality if it matters, but it shouldn't matter from the stand points of proofs.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], [], '∀ {α : Type u} [inhabited α], (∃ x : α, x = x)')
    result = (lean_interface.apply_tactic(goal, "intro, intro"))
    
    # the new goal should be 
    #  {α : Type u} [_inst_1 : inhabited.{u+1} α] ⊢ @Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)
    # but we record it as the slightly different
    #  (α : Type u) (_inst_1 : inhabited.{u+1} α) ⊢ @Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)
    goal2 = result[1][0]
    print(goal2)
    
    # however, the proof is the same
    result = (lean_interface.apply_tactic(goal2, "existsi _inst_1.default, refl"))
    print(result)
# Out:
# LeanGoal(universes=['u'], assumptions=['α : Type u', '_inst_1 : inhabited.{u+1} α'], conclusion='@Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)')
# ('success', [], '')

# %% [markdown]
# ### Let expressions

# %% [markdown]
# The `intro` tactic can move `let` binders to the local context.  However, I don't know a way to either
# 1. figure out that the assumption in the local context is associated with a let binder and know what it is assigned to, nor
# 2. enter this back into Lean.
#
# Consider the following example.

# %%
with LeanTacticTestingInterface() as lean_interface:
    # This is solvable with this proof:
    goal = LeanGoal([], [], 'let x : ℕ := 0 in x = 0')
    proof = "intro, refl"
    result = (lean_interface.apply_tactic(goal, proof))
    print(result)
    
    # but if we do it in two steps, the assumption gets recorded incorrectly:
    goal = LeanGoal([], [], 'let x : ℕ := 0 in x = 0')
    result = (lean_interface.apply_tactic(goal, 'intro'))
    print(result)
    
    goal2 = result[1][0]
    result = (lean_interface.apply_tactic(goal2, 'refl'))
    print(result)
    
    # moveover, even if we enter this as `x : nat := 0` in the assumptions it gets 
    # a different interpretation than we intend.  It interprets this as `x : opt_param nat 0`.
    goal3 = LeanGoal([], ['x : nat := 0'], 'x = 0')
    result = (lean_interface.apply_tactic(goal3, 'skip'))
    print(result)
# Out:
# ('success', [], '')
# ('success', [LeanGoal(universes=[], assumptions=['x : nat'], conclusion='@eq.{1} nat x (@has_zero.zero.{0} nat nat.has_zero)')], '')
# ('tactic_failure', ['invalid apply tactic, failed to unify\n  x = 0\nwith\n  ?m_2 = ?m_2\nstate:\nx : ℕ\n⊢ x = 0'], '')
# ('success', [LeanGoal(universes=[], assumptions=['x : opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)'], conclusion='@eq.{1} (opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)) x (@has_zero.zero.{0} (opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)) nat.has_zero)')], '')

# %% [markdown]
# ### Other

# %% [markdown]
# There are other small issues that sometimes come up, and I'm sure more issues will arise as this is tested on all the theorems in Lean.  However, right now about in the core library, about 95% of theorems correctly load into Lean.  (I imagine that in `mathlib`, with the increased use of type classes, that this number will go down.)

# %% [markdown]
# ## TODOs

# %% [markdown]
# - Code:
#     - Is there a way to make this faster?
#     - Is there a way to make this more robust?  (It works for now, but still feels rickety.)
#     - Make this production level code.  It is just a proof of concept and still quite hacky.
# - Functionality
#     - How should one enter definitions and notation?
#     - Can we even enter all Lean theorems this way (assuming there definitions and notation are stored in mathlib)?
#       - A next step would be to get a list of all theorems and see if we can apply the `skip` tactic to them.
#     - How should one enter premises?  The easiest way is to add them as assumptions to the goal.
#     - ~~What about imports, etc?~~
#     - We only apply tactics to a single goal and not a goal stack

# %% [markdown]
# ## What I want from Lean 4

# %% [markdown]
# - Either a REPL like interface which is fast,
# - or a way to quickly in a few milliseconds call Lean for the text of a small file and get a direct (and unambiguous) response to my request.
# - Better documentation of the communication interface
# - Better documentation of the tactic commands
